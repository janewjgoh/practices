# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from pylab import *

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()

# %%
subplot(1,2,1)
plot(x, y, 'r--')
subplot(1,2,2)
plot(y, x, 'g*-');

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes

# main figure
axes1.plot(x, y, 'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

# insert
axes2.plot(y, x, 'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('insert title');

# %%
df = pd.read_csv("Eating Plan.xlsx")
# To display the top 5 rows 
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8a04efa0399a> in <module>
# ----> 1 df = pd.read_csv("Eating Plan.xlsx")
#       2 # To display the top 5 rows
#       3 df.head(5)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_csv("Eating Plan.csv")
# To display the top 5 rows 
df.tail(5)
# Out:
#    MENU SUMMARY                                         Unnamed: 1 Unnamed: 2  \
# 51          NaN                      White fish; Pork; Prawn Combo      Lunch
# 52          NaN                                   Shrimp Rice Bowl     Dinner
# 53          NaN                                              Total        NaN
# 54          NaN                                                NaN        NaN
# 55          NaN  *WEDNESDAY AND SUNDAY ARE CHEATMEAL DAYSSSSSSS...        NaN
#
#    Unnamed: 3 Unnamed: 4                        Unnamed: 5 Unnamed: 6  \
# 51      82.37     737.66  White fish; Chicken; Prawn Combo      Lunch
# 52      27.97     521.21                  Shrimp Rice Bowl     Dinner
# 53     137.14    2047.87                             Total        NaN
# 54        NaN        NaN                               NaN        NaN
# 55        NaN        NaN                               NaN        NaN
#
#    Unnamed: 7 Unnamed: 8                    Unnamed: 9 Unnamed: 10  \
# ...

# %%
df = df.drop(['MENU SUMMARY'], axis=1)
df.head(5)
# Out:
#                           Unnamed: 1               Unnamed: 2  \
# 0                                NaN                      NaN
# 1                          Breakfast  Protein per portion (g)
# 2         2 Avocado Toasts with Eggs                    22.13
# 3  3 Fried Eggs (Sunny or Scrambled)                       18
# 4                 3 half boiled Eggs                       18
#
#          Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0               NaN        NaN        NaN        NaN        NaN        NaN
# 1  Kcal per portion        NaN        NaN        NaN        NaN        NaN
# 2             659.3        NaN        NaN        NaN        NaN        NaN
# 3               356        NaN        NaN        NaN        NaN        NaN
# 4               234        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# ...

# %%
df = df.rename(columns={"Unnamed:1": "Breakfast", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price" })
df.head(5)
